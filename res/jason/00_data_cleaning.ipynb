# %% [markdown]
# # **1-on_time.csv**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Import
# 1. On-time performance
# 2. Daily weather data (pending)
# 3. Traffic/construction data (pending)

# %%
DF = pd.read_csv("../../datasets/on_time.csv",low_memory=False)
DF
# Out:
#             Row ID  Stop Number Route Number           Route Name  \
# 0        838791619        30893           71            Arlington
# 1        838791621        30894           71            Arlington
# 2        838791623        30884           71            Arlington
# 3        838791626        30377           71            Arlington
# 4        838791628        30378           71            Arlington
# ...            ...          ...          ...                  ...
# 4264663  856899198        40043           47  Transcona - Pembina
# 4264664  856899200        40037           47  Transcona - Pembina
# 4264665  856899202        40031           47  Transcona - Pembina
# 4264666  856899204        40029           47  Transcona - Pembina
# 4264667  856899206        40019           47  Transcona - Pembina
#
#             Route Destination Day Type       Scheduled Time  Deviation  \
# 0        Portage via Sinclair  Weekday  2021-08-03T12:57:00        -83
# 1        Portage via Sinclair  Weekday  2021-08-03T12:57:47       -131
# 2        Portage via Sinclair  Weekday  2021-08-03T12:58:20       -112
# 3        Portage via Sinclair  Weekday  2021-08-03T13:00:00       -128
# 4        Portage via Sinclair  Weekday  2021-08-03T13:01:02       -277
# ...                       ...      ...                  ...        ...
# 4264663  Transcona via Regent  Weekday  2021-08-17T10:26:36       -252
# 4264664  Transcona via Regent  Weekday  2021-08-17T10:27:13       -248
# 4264665  Transcona via Regent  Weekday  2021-08-17T10:27:42       -248
# 4264666  Transcona via Regent  Weekday  2021-08-17T10:28:03       -240
# 4264667  Transcona via Regent  Weekday  2021-08-17T10:28:24       -231
#
#                                               Location
# 0           POINT (-97.1487003222228 49.9583003868781)
# 1        POINT (-97.14473223771209 49.957067630945396)
# 2          POINT (-97.14591991330629 49.9555484932656)
# 3           POINT (-97.1452473007769 49.9523715211324)
# 4           POINT (-97.1409297615775 49.9511780159218)
# ...                                                ...
# 4264663   POINT (-96.99292649366559 49.89504583500769)
# 4264664     POINT (-96.9891662035126 49.8950616196603)
# 4264665   POINT (-96.9867783593948 49.895892701349496)
# 4264666     POINT (-96.9846475305137 49.8959006485947)
# 4264667    POINT (-96.9825580713755 49.89591827184589)
#
# [4264668 rows x 9 columns]

# %%
for col in DF.columns:
    print(col,DF[col].dtype)
# Out:
# Row ID int64
# Stop Number int64
# Route Number object
# Route Name object
# Route Destination object
# Day Type object
# Scheduled Time object
# Deviation int64
# Location object

# %% [markdown]
# # Data Preprocessing
# 1. Remove Row ID
# 2. Convert Scheduled Time column to DateTime format
# 3. Convert Location column to tuple
# 4. Group Route Name and Route Destination into a single column
# 5. Add Delay Type (Early, On-time, Short, Medium, Long, Severe, Crippling)

# %%
# 1
DF = DF.drop(columns="Row ID")
DF
# Out:
#          Stop Number Route Number           Route Name     Route Destination  \
# 0              30893           71            Arlington  Portage via Sinclair
# 1              30894           71            Arlington  Portage via Sinclair
# 2              30884           71            Arlington  Portage via Sinclair
# 3              30377           71            Arlington  Portage via Sinclair
# 4              30378           71            Arlington  Portage via Sinclair
# ...              ...          ...                  ...                   ...
# 4264663        40043           47  Transcona - Pembina  Transcona via Regent
# 4264664        40037           47  Transcona - Pembina  Transcona via Regent
# 4264665        40031           47  Transcona - Pembina  Transcona via Regent
# 4264666        40029           47  Transcona - Pembina  Transcona via Regent
# 4264667        40019           47  Transcona - Pembina  Transcona via Regent
#
#         Day Type       Scheduled Time  Deviation  \
# 0        Weekday  2021-08-03T12:57:00        -83
# 1        Weekday  2021-08-03T12:57:47       -131
# 2        Weekday  2021-08-03T12:58:20       -112
# 3        Weekday  2021-08-03T13:00:00       -128
# 4        Weekday  2021-08-03T13:01:02       -277
# ...          ...                  ...        ...
# 4264663  Weekday  2021-08-17T10:26:36       -252
# 4264664  Weekday  2021-08-17T10:27:13       -248
# 4264665  Weekday  2021-08-17T10:27:42       -248
# 4264666  Weekday  2021-08-17T10:28:03       -240
# 4264667  Weekday  2021-08-17T10:28:24       -231
#
#                                               Location
# 0           POINT (-97.1487003222228 49.9583003868781)
# 1        POINT (-97.14473223771209 49.957067630945396)
# 2          POINT (-97.14591991330629 49.9555484932656)
# 3           POINT (-97.1452473007769 49.9523715211324)
# 4           POINT (-97.1409297615775 49.9511780159218)
# ...                                                ...
# 4264663   POINT (-96.99292649366559 49.89504583500769)
# 4264664     POINT (-96.9891662035126 49.8950616196603)
# 4264665   POINT (-96.9867783593948 49.895892701349496)
# 4264666     POINT (-96.9846475305137 49.8959006485947)
# 4264667    POINT (-96.9825580713755 49.89591827184589)
#
# [4264668 rows x 8 columns]

# %%
# 2
DF['Scheduled Time'] = pd.to_datetime(DF['Scheduled Time'].str.replace('T',' '))
print(DF['Scheduled Time'].dtype)
DF.head()
# Out:
# datetime64[ns]
#    Stop Number Route Number Route Name     Route Destination Day Type  \
# 0        30893           71  Arlington  Portage via Sinclair  Weekday
# 1        30894           71  Arlington  Portage via Sinclair  Weekday
# 2        30884           71  Arlington  Portage via Sinclair  Weekday
# 3        30377           71  Arlington  Portage via Sinclair  Weekday
# 4        30378           71  Arlington  Portage via Sinclair  Weekday
#
#        Scheduled Time  Deviation  \
# 0 2021-08-03 12:57:00        -83
# 1 2021-08-03 12:57:47       -131
# 2 2021-08-03 12:58:20       -112
# 3 2021-08-03 13:00:00       -128
# 4 2021-08-03 13:01:02       -277
#
#                                         Location
# 0     POINT (-97.1487003222228 49.9583003868781)
# 1  POINT (-97.14473223771209 49.957067630945396)
# 2    POINT (-97.14591991330629 49.9555484932656)
# 3     POINT (-97.1452473007769 49.9523715211324)
# 4     POINT (-97.1409297615775 49.9511780159218)

# %%
# 3
def __clean_string(df):
    to_repl = ''
    for pat in ["POINT (",")"]:
        df = df.str.replace(pat,to_repl,regex=False)
    df = df.str.split()
    return df

def as_dtype(lst,dtype):
    if isinstance(lst,(list,tuple)):
        return type(lst)([dtype(i) for i in lst])
    else: return lst

DF['Location'] = __clean_string(DF['Location'])
DF.loc[:,['Long','Lat']] = [as_dtype(i,float) for i in DF['Location'].values]
DF = DF.drop(columns="Location")
DF
# Out:
#          Stop Number Route Number           Route Name     Route Destination  \
# 0              30893           71            Arlington  Portage via Sinclair
# 1              30894           71            Arlington  Portage via Sinclair
# 2              30884           71            Arlington  Portage via Sinclair
# 3              30377           71            Arlington  Portage via Sinclair
# 4              30378           71            Arlington  Portage via Sinclair
# ...              ...          ...                  ...                   ...
# 4264663        40043           47  Transcona - Pembina  Transcona via Regent
# 4264664        40037           47  Transcona - Pembina  Transcona via Regent
# 4264665        40031           47  Transcona - Pembina  Transcona via Regent
# 4264666        40029           47  Transcona - Pembina  Transcona via Regent
# 4264667        40019           47  Transcona - Pembina  Transcona via Regent
#
#         Day Type      Scheduled Time  Deviation       Long        Lat
# 0        Weekday 2021-08-03 12:57:00        -83 -97.148700  49.958300
# 1        Weekday 2021-08-03 12:57:47       -131 -97.144732  49.957068
# 2        Weekday 2021-08-03 12:58:20       -112 -97.145920  49.955548
# 3        Weekday 2021-08-03 13:00:00       -128 -97.145247  49.952372
# 4        Weekday 2021-08-03 13:01:02       -277 -97.140930  49.951178
# ...          ...                 ...        ...        ...        ...
# 4264663  Weekday 2021-08-17 10:26:36       -252 -96.992926  49.895046
# 4264664  Weekday 2021-08-17 10:27:13       -248 -96.989166  49.895062
# 4264665  Weekday 2021-08-17 10:27:42       -248 -96.986778  49.895893
# 4264666  Weekday 2021-08-17 10:28:03       -240 -96.984648  49.895901
# 4264667  Weekday 2021-08-17 10:28:24       -231 -96.982558  49.895918
#
# [4264668 rows x 9 columns]

# %%
# 4
DF['Route'] = tuple([tuple(val) for val in DF[['Route Number','Route Name','Route Destination']].values])
DF = DF.drop(columns=['Route Name','Route Destination'])
DF
# Out:
#          Stop Number Route Number Day Type      Scheduled Time  Deviation  \
# 0              30893           71  Weekday 2021-08-03 12:57:00        -83
# 1              30894           71  Weekday 2021-08-03 12:57:47       -131
# 2              30884           71  Weekday 2021-08-03 12:58:20       -112
# 3              30377           71  Weekday 2021-08-03 13:00:00       -128
# 4              30378           71  Weekday 2021-08-03 13:01:02       -277
# ...              ...          ...      ...                 ...        ...
# 4264663        40043           47  Weekday 2021-08-17 10:26:36       -252
# 4264664        40037           47  Weekday 2021-08-17 10:27:13       -248
# 4264665        40031           47  Weekday 2021-08-17 10:27:42       -248
# 4264666        40029           47  Weekday 2021-08-17 10:28:03       -240
# 4264667        40019           47  Weekday 2021-08-17 10:28:24       -231
#
#               Long        Lat                                            Route
# 0       -97.148700  49.958300            (71, Arlington, Portage via Sinclair)
# 1       -97.144732  49.957068            (71, Arlington, Portage via Sinclair)
# 2       -97.145920  49.955548            (71, Arlington, Portage via Sinclair)
# 3       -97.145247  49.952372            (71, Arlington, Portage via Sinclair)
# 4       -97.140930  49.951178            (71, Arlington, Portage via Sinclair)
# ...            ...        ...                                              ...
# 4264663 -96.992926  49.895046  (47, Transcona - Pembina, Transcona via Regent)
# 4264664 -96.989166  49.895062  (47, Transcona - Pembina, Transcona via Regent)
# 4264665 -96.986778  49.895893  (47, Transcona - Pembina, Transcona via Regent)
# 4264666 -96.984648  49.895901  (47, Transcona - Pembina, Transcona via Regent)
# 4264667 -96.982558  49.895918  (47, Transcona - Pembina, Transcona via Regent)
#
# [4264668 rows x 8 columns]

# %% [markdown]
# Delay types:
# - Early: < -2 min
# - On-time: Within -2 min - <2 min
# - Short delay: 2 min - <10 min,
# - Medium delay: 10 min - <30 min,
# - Long delay: 30 min - <60 min,
# - Severe delay: 60+ min

# %%
# 5 
MIN = 60
dev = DF['Deviation'].copy()
delay_types = {
    'early':    (dev < -2*MIN),
    'on-time':  (-2*MIN <= dev) & (dev < 2*MIN),
    'short' :   (2*MIN <= dev)  & (dev < 10*MIN),
    'medium' :  (10*MIN <= dev) & (dev < 30*MIN),
    'long' :    (30*MIN <= dev) & (dev < 60*MIN),
    'severe' :  (dev >= 60*MIN),
}

for delay_type,cond in delay_types.items():
    type_index = dev[cond].dropna().index
    DF.loc[type_index,'Delay Type'] = delay_type
DF
# Out:
#          Stop Number Route Number Day Type      Scheduled Time  Deviation  \
# 0              30893           71  Weekday 2021-08-03 12:57:00        -83
# 1              30894           71  Weekday 2021-08-03 12:57:47       -131
# 2              30884           71  Weekday 2021-08-03 12:58:20       -112
# 3              30377           71  Weekday 2021-08-03 13:00:00       -128
# 4              30378           71  Weekday 2021-08-03 13:01:02       -277
# ...              ...          ...      ...                 ...        ...
# 4264663        40043           47  Weekday 2021-08-17 10:26:36       -252
# 4264664        40037           47  Weekday 2021-08-17 10:27:13       -248
# 4264665        40031           47  Weekday 2021-08-17 10:27:42       -248
# 4264666        40029           47  Weekday 2021-08-17 10:28:03       -240
# 4264667        40019           47  Weekday 2021-08-17 10:28:24       -231
#
#               Long        Lat  \
# 0       -97.148700  49.958300
# 1       -97.144732  49.957068
# 2       -97.145920  49.955548
# 3       -97.145247  49.952372
# 4       -97.140930  49.951178
# ...            ...        ...
# 4264663 -96.992926  49.895046
# 4264664 -96.989166  49.895062
# 4264665 -96.986778  49.895893
# 4264666 -96.984648  49.895901
# 4264667 -96.982558  49.895918
#
#                                                    Route Delay Type
# 0                  (71, Arlington, Portage via Sinclair)    on-time
# 1                  (71, Arlington, Portage via Sinclair)      early
# 2                  (71, Arlington, Portage via Sinclair)    on-time
# 3                  (71, Arlington, Portage via Sinclair)      early
# 4                  (71, Arlington, Portage via Sinclair)      early
# ...                                                  ...        ...
# 4264663  (47, Transcona - Pembina, Transcona via Regent)      early
# 4264664  (47, Transcona - Pembina, Transcona via Regent)      early
# 4264665  (47, Transcona - Pembina, Transcona via Regent)      early
# 4264666  (47, Transcona - Pembina, Transcona via Regent)      early
# 4264667  (47, Transcona - Pembina, Transcona via Regent)      early
#
# [4264668 rows x 9 columns]

# %%
DF.to_csv("clean_datasets/ON_TIME.csv")

# %% [markdown]
# # **2-traffic_counts.csv**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DF = pd.read_csv("../../datasets/traffic_counts.csv",low_memory=False)
DF
# Out:
#                      Timestamp                                  Site  Right  \
# 0       26/06/2020 11:45:00 PM           Pembina And 280 N Of Adamar    118
# 1       26/06/2020 11:45:00 PM  Henderson And 55M S Of Frasers Grove    110
# 2       26/06/2020 11:00:00 PM    McPhillips And 190m South Of Leila    139
# 3       26/06/2020 11:15:00 PM                   Nichol And St.Marys     86
# 4       26/06/2020 11:15:00 PM             Inkster And 130W Of Wyatt    126
# ...                        ...                                   ...    ...
# 502391  07/10/2021 02:00:00 PM            Marion And 260M E Of Dupuy    170
# 502392  07/10/2021 11:15:00 AM       Lagimodiere And 80M N Of Burmac    277
# 502393  07/10/2021 10:00:00 PM       Lagimodiere And 80M N Of Burmac    122
# 502394  07/10/2021 07:15:00 AM           Pembina And 280 N Of Adamar    179
# 502395  07/10/2021 03:00:00 AM       Lagimodiere And 80M N Of Burmac     20
#
#         Left  Northbound  Southbound  Eastbound  Westbound  Total   Latitude  \
# 0        107       107.0       118.0        NaN        NaN    225  49.826952
# 1         71       110.0        71.0        NaN        NaN    181  49.934985
# 2        149       139.0       149.0        NaN        NaN    288  49.951733
# 3         83        83.0        86.0        NaN        NaN    169  49.850579
# 4         96         NaN         NaN      126.0       96.0    222  49.945949
# ...      ...         ...         ...        ...        ...    ...        ...
# 502391   174         NaN         NaN      170.0      174.0    344  49.881900
# 502392   235       235.0       277.0        NaN        NaN    512  49.848695
# 502393   120       120.0       122.0        NaN        NaN    242  49.848695
# 502394   382       382.0       179.0        NaN        NaN    561  49.826952
# 502395    13        13.0        20.0        NaN        NaN     33  49.848695
#
#         Longitude                      Location
# 0      -97.152312  POINT (-97.152312 49.826952)
# 1      -97.096166  POINT (-97.096166 49.934985)
# 2      -97.149032  POINT (-97.149032 49.951733)
# 3      -97.112202  POINT (-97.112202 49.850579)
# 4      -97.187758  POINT (-97.187758 49.945949)
# ...           ...                           ...
# 502391 -97.089342    POINT (-97.089342 49.8819)
# 502392 -97.049665  POINT (-97.049665 49.848695)
# 502393 -97.049665  POINT (-97.049665 49.848695)
# 502394 -97.152312  POINT (-97.152312 49.826952)
# 502395 -97.049665  POINT (-97.049665 49.848695)
#
# [502396 rows x 12 columns]

# %%
for col in DF.columns:
    print(col,DF[col].dtype)
# Out:
# Timestamp object
# Site object
# Right int64
# Left int64
# Northbound float64
# Southbound float64
# Eastbound float64
# Westbound float64
# Total int64
# Latitude float64
# Longitude float64
# Location object

# %% [markdown]
# # Data Preprocessing
# 1. Convert Timestamp, selecting only periods of interest
# 2. Analyze relationship between Site x Location and {Right,Left} x {N,S,W,E}
# 3. Clean columns if possible

# %%
#1
DF.loc[:,'Timestamp'] = pd.to_datetime(DF['Timestamp'])
print(DF['Timestamp'].dtype)
START_DATE = pd.to_datetime('Aug 1 2021'); END_DATE = pd.to_datetime('Sep 1 2021')
cond = (START_DATE < DF["Timestamp"]) & (DF["Timestamp"] < END_DATE)
DF = DF[cond].sort_values('Timestamp')
DF
# Out:
# datetime64[ns]
#                  Timestamp                                  Site  Right  Left  \
# 308118 2021-08-01 20:00:00    McPhillips And 190m South Of Leila    170   152
# 308119 2021-08-01 02:00:00    McPhillips And 190m South Of Leila     14    15
# 308120 2021-08-01 19:30:00    McPhillips And 190m South Of Leila    181   161
# 308121 2021-08-01 11:15:00    McPhillips And 190m South Of Leila    178   262
# 308122 2021-08-01 04:15:00  Henderson And 55M S Of Frasers Grove     12    12
# ...                    ...                                   ...    ...   ...
# 490102 2021-08-24 14:00:00            Marion And 260M E Of Dupuy    180   198
# 490103 2021-08-24 11:15:00       Lagimodiere And 80M N Of Burmac    282   249
# 490104 2021-08-24 22:00:00       Lagimodiere And 80M N Of Burmac    171   127
# 490105 2021-08-24 07:15:00           Pembina And 280 N Of Adamar    131   326
# 490106 2021-08-24 03:00:00       Lagimodiere And 80M N Of Burmac     13    14
#
#         Northbound  Southbound  Eastbound  Westbound  Total   Latitude  \
# 308118       170.0       152.0        NaN        NaN    322  49.951733
# 308119        14.0        15.0        NaN        NaN     29  49.951733
# 308120       181.0       161.0        NaN        NaN    342  49.951733
# 308121       178.0       262.0        NaN        NaN    440  49.951733
# 308122        12.0        12.0        NaN        NaN     24  49.934985
# ...            ...         ...        ...        ...    ...        ...
# 490102         NaN         NaN      180.0      198.0    378  49.881900
# 490103       249.0       282.0        NaN        NaN    531  49.848695
# 490104       127.0       171.0        NaN        NaN    298  49.848695
# 490105       326.0       131.0        NaN        NaN    457  49.826952
# 490106        14.0        13.0        NaN        NaN     27  49.848695
#
#         Longitude                      Location
# 308118 -97.149032  POINT (-97.149032 49.951733)
# 308119 -97.149032  POINT (-97.149032 49.951733)
# 308120 -97.149032  POINT (-97.149032 49.951733)
# 308121 -97.149032  POINT (-97.149032 49.951733)
# 308122 -97.096166  POINT (-97.096166 49.934985)
# ...           ...                           ...
# 490102 -97.089342    POINT (-97.089342 49.8819)
# 490103 -97.049665  POINT (-97.049665 49.848695)
# 490104 -97.049665  POINT (-97.049665 49.848695)
# 490105 -97.152312  POINT (-97.152312 49.826952)
# 490106 -97.049665  POINT (-97.049665 49.848695)
#
# [21495 rows x 12 columns]

# %%
sites = DF.loc[:,"Site"].str.split().values
DF.loc[:,["Street","Near"]] = [[l[0],l[-1]] for l in sites]
DF
# Out:
# /Users/jasetran/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
#                  Timestamp                                  Site  Right  Left  \
# 308118 2021-08-01 20:00:00    McPhillips And 190m South Of Leila    170   152
# 308119 2021-08-01 02:00:00    McPhillips And 190m South Of Leila     14    15
# 308120 2021-08-01 19:30:00    McPhillips And 190m South Of Leila    181   161
# 308121 2021-08-01 11:15:00    McPhillips And 190m South Of Leila    178   262
# 308122 2021-08-01 04:15:00  Henderson And 55M S Of Frasers Grove     12    12
# ...                    ...                                   ...    ...   ...
# 490102 2021-08-24 14:00:00            Marion And 260M E Of Dupuy    180   198
# 490103 2021-08-24 11:15:00       Lagimodiere And 80M N Of Burmac    282   249
# 490104 2021-08-24 22:00:00       Lagimodiere And 80M N Of Burmac    171   127
# 490105 2021-08-24 07:15:00           Pembina And 280 N Of Adamar    131   326
# 490106 2021-08-24 03:00:00       Lagimodiere And 80M N Of Burmac     13    14
#
#         Northbound  Southbound  Eastbound  Westbound  Total   Latitude  \
# 308118       170.0       152.0        NaN        NaN    322  49.951733
# 308119        14.0        15.0        NaN        NaN     29  49.951733
# 308120       181.0       161.0        NaN        NaN    342  49.951733
# 308121       178.0       262.0        NaN        NaN    440  49.951733
# 308122        12.0        12.0        NaN        NaN     24  49.934985
# ...            ...         ...        ...        ...    ...        ...
# 490102         NaN         NaN      180.0      198.0    378  49.881900
# 490103       249.0       282.0        NaN        NaN    531  49.848695
# 490104       127.0       171.0        NaN        NaN    298  49.848695
# 490105       326.0       131.0        NaN        NaN    457  49.826952
# 490106        14.0        13.0        NaN        NaN     27  49.848695
#
#         Longitude                      Location       Street    Near
# 308118 -97.149032  POINT (-97.149032 49.951733)   McPhillips   Leila
# 308119 -97.149032  POINT (-97.149032 49.951733)   McPhillips   Leila
# 308120 -97.149032  POINT (-97.149032 49.951733)   McPhillips   Leila
# 308121 -97.149032  POINT (-97.149032 49.951733)   McPhillips   Leila
# 308122 -97.096166  POINT (-97.096166 49.934985)    Henderson   Grove
# ...           ...                           ...          ...     ...
# 490102 -97.089342    POINT (-97.089342 49.8819)       Marion   Dupuy
# 490103 -97.049665  POINT (-97.049665 49.848695)  Lagimodiere  Burmac
# 490104 -97.049665  POINT (-97.049665 49.848695)  Lagimodiere  Burmac
# 490105 -97.152312  POINT (-97.152312 49.826952)      Pembina  Adamar
# 490106 -97.049665  POINT (-97.049665 49.848695)  Lagimodiere  Burmac
#
# [21495 rows x 14 columns]

# %%
DF = DF.drop(columns=["Right","Left","Location"]).rename(columns={"Latitude":"Lat","Longitude":"Long"})
DF.to_csv("clean_datasets/TRAFFIC_COUNTS.csv")
DF
# Out:
#                  Timestamp                                  Site  Northbound  \
# 308118 2021-08-01 20:00:00    McPhillips And 190m South Of Leila       170.0
# 308119 2021-08-01 02:00:00    McPhillips And 190m South Of Leila        14.0
# 308120 2021-08-01 19:30:00    McPhillips And 190m South Of Leila       181.0
# 308121 2021-08-01 11:15:00    McPhillips And 190m South Of Leila       178.0
# 308122 2021-08-01 04:15:00  Henderson And 55M S Of Frasers Grove        12.0
# ...                    ...                                   ...         ...
# 490102 2021-08-24 14:00:00            Marion And 260M E Of Dupuy         NaN
# 490103 2021-08-24 11:15:00       Lagimodiere And 80M N Of Burmac       249.0
# 490104 2021-08-24 22:00:00       Lagimodiere And 80M N Of Burmac       127.0
# 490105 2021-08-24 07:15:00           Pembina And 280 N Of Adamar       326.0
# 490106 2021-08-24 03:00:00       Lagimodiere And 80M N Of Burmac        14.0
#
#         Southbound  Eastbound  Westbound  Total        Lat       Long  \
# 308118       152.0        NaN        NaN    322  49.951733 -97.149032
# 308119        15.0        NaN        NaN     29  49.951733 -97.149032
# 308120       161.0        NaN        NaN    342  49.951733 -97.149032
# 308121       262.0        NaN        NaN    440  49.951733 -97.149032
# 308122        12.0        NaN        NaN     24  49.934985 -97.096166
# ...            ...        ...        ...    ...        ...        ...
# 490102         NaN      180.0      198.0    378  49.881900 -97.089342
# 490103       282.0        NaN        NaN    531  49.848695 -97.049665
# 490104       171.0        NaN        NaN    298  49.848695 -97.049665
# 490105       131.0        NaN        NaN    457  49.826952 -97.152312
# 490106        13.0        NaN        NaN     27  49.848695 -97.049665
#
#              Street    Near
# 308118   McPhillips   Leila
# 308119   McPhillips   Leila
# 308120   McPhillips   Leila
# 308121   McPhillips   Leila
# 308122    Henderson   Grove
# ...             ...     ...
# 490102       Marion   Dupuy
# 490103  Lagimodiere  Burmac
# 490104  Lagimodiere  Burmac
# 490105      Pembina  Adamar
# 490106  Lagimodiere  Burmac
#
# [21495 rows x 11 columns]

# %%
#2
DF_SITES = DF[["Site","Street","Near","Lat","Long"]].drop_duplicates().set_index("Site")
DF_SITES.to_csv("clean_datasets/SITES.csv")
DF_SITES
# Out:
#                                            Street      Near        Lat  \
# Site
# McPhillips And 190m South Of Leila     McPhillips     Leila  49.951733
# Henderson And 55M S Of Frasers Grove    Henderson     Grove  49.934985
# Pembina And 280 N Of Adamar               Pembina    Adamar  49.826952
# Inkster And 130W Of Wyatt                 Inkster     Wyatt  49.945949
# Nichol And St.Marys                        Nichol  St.Marys  49.850579
# Lagimodiere And 80M N Of Burmac       Lagimodiere    Burmac  49.848695
# Disraeli Bridge                          Disraeli    Bridge  49.906744
# Marion And 260M E Of Dupuy                 Marion     Dupuy  49.881900
#
#                                            Long
# Site
# McPhillips And 190m South Of Leila   -97.149032
# Henderson And 55M S Of Frasers Grove -97.096166
# Pembina And 280 N Of Adamar          -97.152312
# Inkster And 130W Of Wyatt            -97.187758
# Nichol And St.Marys                  -97.112202
# Lagimodiere And 80M N Of Burmac      -97.049665
# Disraeli Bridge                      -97.123028
# Marion And 260M E Of Dupuy           -97.089342

# %% [markdown]
# # **3-stops.csv**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DF = pd.read_csv("../../datasets/stops.csv",low_memory=False)
DF
# Out:
#       stop_id  stop_code                          stop_name   stop_lat  \
# 0       10001      10001       Southbound Osborne at Mulvey  49.871261
# 1       10002      10002     Southbound Osborne at Woodward  49.868819
# 2       10003      10003      Southbound Osborne at Brandon  49.867880
# 3       10004      10004  Southbound Osborne at Hethrington  49.866522
# 4       10005      10005       Southbound Osborne at Morley  49.865164
# ...       ...        ...                                ...        ...
# 5151    62018      62018       Eastbound Parker at Beaumont  49.847806
# 5152    62021      62021   Northbound Eaglewood at Longspur  49.780139
# 5153    62022      62022   Southbound Eaglewood at Longspur  49.780498
# 5154    62023      62023       Westbound Bison at Appleford  49.791002
# 5155    62024      62024     Eastbound Bison at Bridge Lake  49.791361
#
#        stop_lon                                    stop_url
# 0    -97.139518  http://www.winnipegtransit.com/stops/10001
# 1    -97.137553  http://www.winnipegtransit.com/stops/10002
# 2    -97.136795  http://www.winnipegtransit.com/stops/10003
# 3    -97.135707  http://www.winnipegtransit.com/stops/10004
# 4    -97.134604  http://www.winnipegtransit.com/stops/10005
# ...         ...                                         ...
# 5151 -97.164596  http://www.winnipegtransit.com/stops/62018
# 5152 -97.196271  http://www.winnipegtransit.com/stops/62021
# 5153 -97.196785  http://www.winnipegtransit.com/stops/62022
# 5154 -97.209359  http://www.winnipegtransit.com/stops/62023
# 5155 -97.206400  http://www.winnipegtransit.com/stops/62024
#
# [5156 rows x 6 columns]

# %%
for col in DF.columns:
    print(col,DF[col].dtype)
# Out:
# stop_id int64
# stop_code int64
# stop_name object
# stop_lat float64
# stop_lon float64
# stop_url object

# %%
df = DF[DF["stop_name"].str.contains("Station")][["stop_id","stop_name"]]
df.head(25)
# Out:
#       stop_id                                          stop_name
# 33      10038  Northbound Daly at Morley (95 to Riverview via...
# 557     10625        Northbound Main at Broadway (Union Station)
# 572     10641        Southbound Main at Broadway (Union Station)
# 719     10831     Northbound Balmoral at Balmoral Station (BLUE)
# 729     10844   Northbound Balmoral at Balmoral Station (48, 49)
# 730     10845       Northbound Balmoral at Balmoral Station (46)
# 731     10846       Northbound Balmoral at Balmoral Station (42)
# 745     10910              Northbound Osborne at Osborne Station
# 746     10911              Southbound Osborne at Osborne Station
# 754     11027  Southbound Southwest Transitway at Harkness St...
# 755     11028  Northbound Southwest Transitway at Harkness St...
# 756     11029  Southbound Southwest Transitway at Osborne Sta...
# 757     11030  Northbound Southwest Transitway at Osborne Sta...
# 758     11031  Southbound Southwest Transitway at Fort Rouge ...
# 759     11032  Northbound Southwest Transitway at Fort Rouge ...
# 760     11033  Southbound Southwest Transitway at Jubilee Sta...
# 761     11034  Northbound Southwest Transitway at Jubilee Sta...
# 764     11037  Southbound Fort Rouge Station at Fort Rouge St...
# 765     11038  Southbound Fort Rouge Station at Fort Rouge St...
# 773     11046  Southbound Southwest Transitway at Harkness St...
# 1612    30337  Northbound McPhillips at Jarvis (McPhillips St...
# 1613    30338  Southbound McPhillips at Jarvis North (McPhill...
# 2946    40777  Southbound Crossroads Station Access at Regent...
# 2947    40778  Northbound Crossroads Station Access at Regent...
# 2948    40780   Northbound Crossroads Station Access at Wal-Mart

# %%
[[l[0].split()[0]," ".join(l[0].split()[1:]),l[1]] for l in df["stop_name"].str.split(" at ")]
# Out:
# [['Northbound', 'Daly', 'Morley (95 to Riverview via Ft Rouge Station)'],
#  ['Northbound', 'Main', 'Broadway (Union Station)'],
#  ['Southbound', 'Main', 'Broadway (Union Station)'],
#  ['Northbound', 'Balmoral', 'Balmoral Station (BLUE)'],
#  ['Northbound', 'Balmoral', 'Balmoral Station (48, 49)'],
#  ['Northbound', 'Balmoral', 'Balmoral Station (46)'],
#  ['Northbound', 'Balmoral', 'Balmoral Station (42)'],
#  ['Northbound', 'Osborne', 'Osborne Station'],
#  ['Southbound', 'Osborne', 'Osborne Station'],
#  ['Southbound', 'Southwest Transitway', 'Harkness Station'],
#  ['Northbound', 'Southwest Transitway', 'Harkness Station'],
#  ['Southbound', 'Southwest Transitway', 'Osborne Station'],
#  ['Northbound', 'Southwest Transitway', 'Osborne Station'],
#  ['Southbound', 'Southwest Transitway', 'Fort Rouge Station'],
#  ['Northbound', 'Southwest Transitway', 'Fort Rouge Station'],
#  ['Southbound', 'Southwest Transitway', 'Jubilee Station'],
#  ['Northbound', 'Southwest Transitway', 'Jubilee Station'],
#  ['Southbound', 'Fort Rouge Station', 'Fort Rouge Station (Route 95)'],
#  ['Southbound', 'Fort Rouge Station', 'Fort Rouge Station (95 to Riverview)'],
#  ['Southbound', 'Southwest Transitway', 'Harkness Station'],
#  ['Northbound', 'McPhillips', 'Jarvis (McPhillips Station)'],
#  ['Southbound', 'McPhillips', 'Jarvis North (McPhillips Station)'],
#  ['Southbound', 'Crossroads Station Access', 'Regent South'],
#  ['Northbound', 'Crossroads Station Access', 'Regent South'],
#  ['Northbound', 'Crossroads Station Access', 'Wal-Mart'],
#  ['Westbound', 'Dafoe', 'U of M Station (662, 671, 672)'],
#  ['Westbound', 'Dafoe', 'U of M Station (74, 75, 78)'],
#  ['Westbound', 'Dafoe', 'U of M Station (36, 47, 60)'],
#  ['Westbound', 'Dafoe', 'U of M Station (BLUE)'],
#  ['Southbound', 'Pembina', 'Station'],
#  ['Northbound', 'Southwest Transitway', 'Beaumont Station'],
#  ['Southbound', 'Southwest Transitway', 'Beaumont Station'],
#  ['Northbound', 'Southwest Transitway', 'Seel Station'],
#  ['Southbound', 'Southwest Transitway', 'Seel Station'],
#  ['Northbound', 'Southwest Transitway', 'Clarence Station'],
#  ['Southbound', 'Southwest Transitway', 'Clarence Station'],
#  ['Northbound', 'Southwest Transitway', 'Chevrier Station'],
#  ['Southbound', 'Southwest Transitway', 'Chevrier Station'],
#  ['Northbound', 'Southwest Transitway', 'Plaza Station'],
#  ['Southbound', 'Southwest Transitway', 'Plaza Station'],
#  ['Northbound', 'Southwest Transitway', 'Chancellor Station'],
#  ['Southbound', 'Southwest Transitway', 'Chancellor Station'],
#  ['Westbound', 'Southpark', 'Southpark Station'],
#  ['Eastbound', 'Southpark', 'Southpark Station'],
#  ['Northbound', 'Southwest Transitway', 'Markham Station'],
#  ['Southbound', 'Southwest Transitway', 'Markham Station'],
#  ['Eastbound', 'Bohemier', 'University Crescent - IGF Station'],
#  ['Eastbound', 'Dafoe', 'U of M Station'],
#  ['Westbound', 'Bohemier', 'University Crescent - IGF Station'],
#  ['Northbound', 'Seel Station', 'Seel Station'],
#  ['Northbound', 'Seel Station', 'Seel Station'],
#  ['Northbound', 'Seel Station', 'Seel Station'],
#  ['Northbound', 'Southwest Transitway', 'Beaumont Station (Route 29)'],
#  ['Southbound', 'Southwest Transitway', 'Beaumont Station (Routes 641, 677)'],
#  ['Westbound', 'Markham', 'Markham Station'],
#  ['Northbound', 'Seel Station', 'Seel Station']]

# %%
DF.loc[:,["Direction","Street","At"]] = [[l[0].split()[0]," ".join(l[0].split()[1:]),l[1]] for l in DF["stop_name"].str.split(" at ")]
DF = DF.rename(columns={"stop_id":"Stop Number","stop_lat":"Lat","stop_lon":"Long","stop_name":"Stop Name"})
DF = DF.drop(columns=["stop_code","stop_url"])
DF
# Out:
#       Stop Number                          Stop Name        Lat       Long  \
# 0           10001       Southbound Osborne at Mulvey  49.871261 -97.139518
# 1           10002     Southbound Osborne at Woodward  49.868819 -97.137553
# 2           10003      Southbound Osborne at Brandon  49.867880 -97.136795
# 3           10004  Southbound Osborne at Hethrington  49.866522 -97.135707
# 4           10005       Southbound Osborne at Morley  49.865164 -97.134604
# ...           ...                                ...        ...        ...
# 5151        62018       Eastbound Parker at Beaumont  49.847806 -97.164596
# 5152        62021   Northbound Eaglewood at Longspur  49.780139 -97.196271
# 5153        62022   Southbound Eaglewood at Longspur  49.780498 -97.196785
# 5154        62023       Westbound Bison at Appleford  49.791002 -97.209359
# 5155        62024     Eastbound Bison at Bridge Lake  49.791361 -97.206400
#
#        Direction     Street           At
# 0     Southbound    Osborne       Mulvey
# 1     Southbound    Osborne     Woodward
# 2     Southbound    Osborne      Brandon
# 3     Southbound    Osborne  Hethrington
# 4     Southbound    Osborne       Morley
# ...          ...        ...          ...
# 5151   Eastbound     Parker     Beaumont
# 5152  Northbound  Eaglewood     Longspur
# 5153  Southbound  Eaglewood     Longspur
# 5154   Westbound      Bison    Appleford
# 5155   Eastbound      Bison  Bridge Lake
#
# [5156 rows x 7 columns]

# %%
DF.to_csv("clean_datasets/STOPS.csv")

# %% [markdown]
# # **4-closure.csv**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DF = pd.read_csv("../../datasets/lane_closure.csv",low_memory=False)
DF.head()
# Out:
#   Primary Street Cross Street                  Boundaries  \
# 0       Bryce St     River Av             River Av to End
# 1       Lilac St    Carter Av  Carter Av to Weatherdon Av
# 2    Princess St   Pacific Av     Pacific Av to Rupert Av
# 3       Henry Av    Austin St            Austin St to End
# 4     Grandin St     Tache Av    Tache Av to St Joseph St
#
#                Direction Date Closed - From  Date Closed - To  \
# 0  Eastbound & Westbound     August 16 2021   October 16 2021
# 1             Southbound       June 14 2021   October 29 2021
# 2             Southbound     August 14 2020   October 16 2021
# 3              Westbound        May 10 2021  November 30 2021
# 4              Eastbound        May 31 2021   January 13 2022
#
#                                       Traffic Effect  \
# 0  Eastbound curb lane, closed for building const...
# 1  East side sidewalk, closed for building constr...
# 2  West side sidewalk, covered by pedestrian scaf...
# 3  Westbound right turnaround lane, closed for st...
# 4  South side sidewalk, closed for building const...
#
#                      Organization Time Closed - From Time Closed - To  ...  \
# 0                           Zelko           12:00 AM         12:00 AM  ...
# 1      Globeland Construction Ltd           12:00 AM         12:00 AM  ...
# 2               Hofer Const. Ltd.           12:00 AM         12:00 AM  ...
# 3  Bockstael Construction Limited           12:00 AM         11:00 PM  ...
# 4                         Qualico           12:00 AM         12:00 AM  ...
#
#             Inserted Date Geometry Id   Status  Complete Closure  \
# 0  08/11/2021 06:37:43 PM      552963  Current                No
# 1  06/09/2021 10:35:09 AM      550863  Current                No
# 2  05/21/2021 12:12:59 PM      550250  Current                No
# 3  05/20/2021 09:32:11 AM      550156  Current                No
# 4  05/26/2021 03:38:27 PM      550361  Current                No
#
#                                                  KML   Latitude  Longitude  \
# 0  <LineString><extrude>0</extrude><tessellate>0<...  49.879699 -97.142781
# 1  <LineString><extrude>0</extrude><tessellate>0<...  49.862454 -97.151445
# 2  <LineString><extrude>0</extrude><tessellate>0<...  49.901786 -97.139766
# 3  <LineString><extrude>0</extrude><tessellate>0<...  49.903340 -97.134152
# 4  <LineString><extrude>0</extrude><tessellate>0<...  49.896013 -97.126315
#
#                X             Y  \
# 0  633429.365245  5.526909e+06
# 1  632854.263781  5.524977e+06
# 2  633584.982267  5.529370e+06
# 3  633983.759759  5.529553e+06
# 4  634566.885434  5.528752e+06
#
#                                             Geometry
# 0  MULTILINESTRING ((-97.142387643857 49.87915381...
# 1  MULTILINESTRING ((-97.151173092203 49.86211919...
# 2  MULTILINESTRING ((-97.139915854251 49.90158994...
# 3  MULTILINESTRING ((-97.13466284795 49.903503694...
# 4  MULTILINESTRING ((-97.127616387474 49.89567885...
#
# [5 rows x 22 columns]

# %%
for col in DF.columns:
    print(col,DF[col].dtype)
# Out:
# Primary Street object
# Cross Street object
# Boundaries object
# Direction object
# Date Closed - From object
# Date Closed - To object
# Traffic Effect object
# Organization object
# Time Closed - From object
# Time Closed - To object
# Lane Closure ID int64
# Modified Date object
# Inserted Date object
# Geometry Id int64
# Status object
# Complete Closure object
# KML object
# Latitude float64
# Longitude float64
# X float64
# Y float64
# Geometry object

# %%
DF = pd.read_csv("../../datasets/lane_closure.csv",low_memory=False)
DF = DF.rename(columns={"Primary Street":"Street","Cross Street":"At","Latitude":"Lat","Longitude":"Long"})
DF.loc[:,"Street"] = [" ".join(l[:-1]) for l in DF["Street"].str.split()]
DF.loc[:,"At"] = [" ".join(l[:-1]) for l in DF["At"].str.split()]
DF.loc[:,"Boundaries"] = DF["Boundaries"].str.split(" to ")
DF.loc[:,"Direction"] = DF["Direction"].str.split(" & ")
__clean_string = lambda l: [[[(float(j.split()[1]),float(j.split()[0])) for j in s.split(", ")] for s in m] for m in l.values]
DF.loc[:,"Geometry"] = __clean_string(DF["Geometry"].str.replace("MULTILINESTRING \(\(|\)\)","",regex=True).replace().str.split("\), \("))
# DF["Geometry"] = DF["Geometry"].str.strip("MULTILINESTRING \(|\)").str.split("\), \(")
# DF["Geometry"] = [[to_tuple_l(s,rev=True,dtype=float,strip_l="(|)",split_l=", ",split=" ") for s in m] for m in DF["Geometry"].values]
DF["Date Closed - From"] = pd.to_datetime(DF["Date Closed - From"]) 
DF["Date Closed - To"] = pd.to_datetime(DF["Date Closed - To"]) 

def _num_points(m): 
    set_i = set()
    for l in m: set_i |= set(l)
    return set_i 
DF["Num_Segments"] = [len(i) for i in DF["Geometry"].values]
DF["Num_Points"] = [len(_num_points(i)) for i in DF["Geometry"].values]

DF = DF.drop(columns=["Traffic Effect","Organization","Lane Closure ID","Modified Date","Inserted Date","Geometry Id","Status","KML","X","Y"])
DF
# Out:
# /Users/jasetran/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3162: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).ndim
#            Street           At                     Boundaries  \
# 0           Bryce        River                [River Av, End]
# 1           Lilac       Carter     [Carter Av, Weatherdon Av]
# 2        Princess      Pacific        [Pacific Av, Rupert Av]
# 3           Henry       Austin               [Austin St, End]
# 4         Grandin        Tache       [Tache Av, St Joseph St]
# ..            ...          ...                            ...
# 425     Sherbrook        Logan         [Logan Av, William Av]
# 426     Gull Lake      Markham     [Markham Rd, East Lake Dr]
# 427       Wardlaw      Osborne         [Osborne St, Scott St]
# 428  Scotsborough   Beckinsale  [Beckinsale By, Novavista Dr]
# 429          Hirt  Ashworth St  [Ashworth St S, Southglen Bv]
#
#                     Direction Date Closed - From Date Closed - To  \
# 0      [Eastbound, Westbound]         2021-08-16       2021-10-16
# 1                [Southbound]         2021-06-14       2021-10-29
# 2                [Southbound]         2020-08-14       2021-10-16
# 3                 [Westbound]         2021-05-10       2021-11-30
# 4                 [Eastbound]         2021-05-31       2022-01-13
# ..                        ...                ...              ...
# 425              [Southbound]         2021-09-20       2021-11-01
# 426  [Northbound, Southbound]         2021-09-17       2021-10-08
# 427               [Eastbound]         2021-09-20       2021-10-15
# 428              [Southbound]         2021-09-23       2021-10-13
# 429              [Southbound]         2021-09-23       2021-10-13
#
#     Time Closed - From Time Closed - To Complete Closure        Lat  \
# 0             12:00 AM         12:00 AM               No  49.879699
# 1             12:00 AM         12:00 AM               No  49.862454
# 2             12:00 AM         12:00 AM               No  49.901786
# 3             12:00 AM         11:00 PM               No  49.903340
# 4             12:00 AM         12:00 AM               No  49.896013
# ..                 ...              ...              ...        ...
# 425           12:00 AM         12:00 AM               No  49.906584
# 426           12:00 AM         12:00 AM               No  49.809311
# 427           12:00 AM         12:00 AM               No  49.877534
# 428           12:00 AM         12:00 AM               No  49.820905
# 429           12:00 AM         12:00 AM               No  49.818463
#
#           Long                                           Geometry  \
# 0   -97.142781  [[(49.879153816388, -97.142387643857), (49.880...
# 1   -97.151445  [[(49.862119196838, -97.151173092203), (49.862...
# 2   -97.139766  [[(49.90158994935, -97.139915854251), (49.9019...
# 3   -97.134152  [[(49.903503694415, -97.13466284795), (49.9033...
# 4   -97.126315  [[(49.895678857718, -97.127616387474), (49.896...
# ..         ...                                                ...
# 425 -97.153705  [[(49.904179261579, -97.155653416614), (49.904...
# 426 -97.158976  [[(49.80730904568, -97.158914003228), (49.8081...
# 427 -97.142232  [[(49.876961712509, -97.143938755153), (49.877...
# 428 -97.107388  [[(49.820524519173, -97.107184511392), (49.820...
# 429 -97.090621  [[(49.817829455747, -97.091126663962), (49.817...
#
#      Num_Segments  Num_Points
# 0               1           3
# 1               1           5
# 2               1           3
# 3               1           4
# 4               1           2
# ..            ...         ...
# 425             1          30
# 426             1          39
# 427             1           5
# 428             1           4
# 429             1          27
#
# [430 rows x 14 columns]

# %%
START_DATE = pd.to_datetime('Aug 1 2021'); END_DATE = pd.to_datetime('Sep 1 2021')
cond = (START_DATE > DF["Date Closed - From"]) & (DF["Date Closed - To"] >= END_DATE)
DF_AUG = DF[cond]
DF_AUG
# Out:
#           Street         At                   Boundaries  \
# 1          Lilac     Carter   [Carter Av, Weatherdon Av]
# 2       Princess    Pacific      [Pacific Av, Rupert Av]
# 3          Henry     Austin             [Austin St, End]
# 4        Grandin      Tache     [Tache Av, St Joseph St]
# 5       Edmonton    St Mary      [St Mary Av, Graham Av]
# ..           ...        ...                          ...
# 367   University      Dafoe       [Dafoe Rd, Markham Rd]
# 370    Charlotte                                [At End]
# 385     Keewatin      Logan       [Logan Av, Selkirk Av]
# 397       Munroe  Henderson   [Henderson Hw, Golspie St]
# 406  Lagimodiere    Capston  [Capston Rd, Sage Creek Bv]
#
#                     Direction Date Closed - From Date Closed - To  \
# 1                [Southbound]         2021-06-14       2021-10-29
# 2                [Southbound]         2020-08-14       2021-10-16
# 3                 [Westbound]         2021-05-10       2021-11-30
# 4                 [Eastbound]         2021-05-31       2022-01-13
# 5                [Northbound]         2021-03-07       2021-10-22
# ..                        ...                ...              ...
# 367  [Northbound, Southbound]         2021-07-23       2021-10-29
# 370    [Eastbound, Westbound]         2021-06-28       2021-11-01
# 385  [Northbound, Southbound]         2021-07-27       2021-10-22
# 397               [Westbound]         2021-05-03       2021-10-08
# 406              [Northbound]         2021-07-26       2021-10-15
#
#     Time Closed - From Time Closed - To Complete Closure        Lat  \
# 1             12:00 AM         12:00 AM               No  49.862454
# 2             12:00 AM         12:00 AM               No  49.901786
# 3             12:00 AM         11:00 PM               No  49.903340
# 4             12:00 AM         12:00 AM               No  49.896013
# 5             11:00 PM         11:59 PM               No  49.890486
# ..                 ...              ...              ...        ...
# 367           12:00 AM         12:00 AM              Yes  49.808929
# 370           12:00 AM         12:00 AM              Yes  49.882473
# 385           12:00 AM         12:00 AM               No  49.926892
# 397           12:00 AM         12:00 AM              Yes  49.919450
# 406           12:00 AM         12:00 AM               No  49.839177
#
#           Long                                           Geometry  \
# 1   -97.151445  [[(49.862119196838, -97.151173092203), (49.862...
# 2   -97.139766  [[(49.90158994935, -97.139915854251), (49.9019...
# 3   -97.134152  [[(49.903503694415, -97.13466284795), (49.9033...
# 4   -97.126315  [[(49.895678857718, -97.127616387474), (49.896...
# 5   -97.146188  [[(49.889751350198, -97.145788366233), (49.889...
# ..         ...                                                ...
# 367 -97.142052  [[(49.805997754019, -97.138668665141), (49.807...
# 370 -97.096175  [[(49.882472182984, -97.096611651835), (49.882...
# 385 -97.195248  [[(49.921824144979, -97.195915153849), (49.921...
# 397 -97.103062  [[(49.92159361799, -97.109515392943), (49.9214...
# 406 -97.049549  [[(49.840279352993, -97.049518603176), (49.840...
#
#      Num_Segments  Num_Points
# 1               1           5
# 2               1           3
# 3               1           4
# 4               1           2
# 5               1           4
# ..            ...         ...
# 367             1          28
# 370             1           2
# 385             3          61
# 397             1           7
# 406             2           9
#
# [65 rows x 14 columns]

# %%
# DF.to_csv("clean_datasets/LANE_CLOSURE.csv")
DF_AUG.to_csv("clean_datasets/LANE_CLOSURE_AUG_2021.csv")

# %% [markdown]
# # **5.road_network**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DF = pd.read_csv("../../datasets/road_network.csv",low_memory=False)
for col in DF.columns:
    print(col,DF[col].dtype)
DF
# Out:
# ID int64
# Block ID float64
# Street Name object
# Street Type object
# Street Direction object
# Street Class object
# Street Type Secondary object
# Street Qualifier object
# Street Qualifier Secondary object
# Address From Left float64
# Address To Left float64
# Address From Right float64
# Address To Right float64
# Number of Lanes float64
# Oneway int64
# Has Reversed Geometry float64
# Speed Limit int64
# Speed Limit Description object
# Speed Limit Jurisdiction object
# Location object
#           ID  Block ID  Street Name Street Type Street Direction Street Class  \
# 0      23480    1873.0       Sifton          Rd              NaN     Arterial
# 1       6648   23974.0        Valde         Ave              NaN        Local
# 2      15347   23779.0  Lagimodiere        Blvd              NaN     Arterial
# 3      30035   70342.0   Sage Creek        Blvd              NaN    Collector
# 4      19001   24031.0        Point          Rd              NaN    Collector
# ...      ...       ...          ...         ...              ...          ...
# 28957  29646   17669.0       Newton         Ave              NaN        Local
# 28958   8062   23040.0         Main          St              NaN     Arterial
# 28959   6592   18560.0        Digby         Ave              NaN        Local
# 28960   8584   24835.0     Disraeli         Fwy              NaN     Arterial
# 28961  18267    4370.0       Taylor         Ave              NaN     Arterial
#
#       Street Type Secondary Street Qualifier Street Qualifier Secondary  \
# 0                    Street                A                        NaN
# 1                    Street                A                        NaN
# 2                    Street                A                        NaN
# 3                    Street                B                        NaN
# 4                    Street                A                        NaN
# ...                     ...              ...                        ...
# 28957                Street                A                        NaN
# 28958                Street                A                        NaN
# 28959                Street                A                        NaN
# 28960                Street                B                        NaN
# 28961                Street                A                        NaN
#
#        Address From Left  Address To Left  Address From Right  \
# 0                    NaN              NaN                 NaN
# 1                   19.0             19.0                22.0
# 2                    NaN              NaN                 NaN
# 3                    NaN              NaN                 0.0
# 4                    NaN              NaN                 NaN
# ...                  ...              ...                 ...
# 28957              258.0            328.0               255.0
# 28958              782.0            782.0                 NaN
# 28959               15.0             27.0                 NaN
# 28960                NaN              NaN                 NaN
# 28961                NaN              NaN                 NaN
#
#        Address To Right  Number of Lanes  Oneway  Has Reversed Geometry  \
# 0                   NaN              2.0       0                    0.0
# 1                  50.0              2.0       0                    0.0
# 2                   NaN              2.0       1                    0.0
# 3                   0.0              2.0       2                    0.0
# 4                   NaN              2.0       0                    0.0
# ...                 ...              ...     ...                    ...
# 28957             325.0              2.0       0                    0.0
# 28958               NaN              3.0       1                    0.0
# 28959               NaN              2.0       0                    0.0
# 28960               NaN              3.0       2                    0.0
# 28961               NaN              2.0       2                    0.0
#
#        Speed Limit                        Speed Limit Description  \
# 0               50  Speed Limits are less than or equal to 50 kph
# 1               50  Speed Limits are less than or equal to 50 kph
# 2               80                      Posted 80 kph speed limit
# 3               50  Speed Limits are less than or equal to 50 kph
# 4               50  Speed Limits are less than or equal to 50 kph
# ...            ...                                            ...
# 28957           50  Speed Limits are less than or equal to 50 kph
# 28958           50  Speed Limits are less than or equal to 50 kph
# 28959           50  Speed Limits are less than or equal to 50 kph
# 28960           60                      Posted 60 kph speed limit
# 28961           60                      Posted 60 kph speed limit
#
#       Speed Limit Jurisdiction  \
# 0          City_Transportation
# 1          City_Transportation
# 2                         City
# 3          City_Transportation
# 4          City_Transportation
# ...                        ...
# 28957      City_Transportation
# 28958      City_Transportation
# 28959      City_Transportation
# 28960                     City
# 28961                     City
#
#                                                 Location
# 0      MULTILINESTRING ((-97.143794801994 49.81055738...
# 1      MULTILINESTRING ((-97.003620088172 49.91094071...
# 2      MULTILINESTRING ((-97.066599484474 49.86715578...
# 3      MULTILINESTRING ((-97.049568380871 49.83374749...
# 4      MULTILINESTRING ((-97.145356293446 49.84697663...
# ...                                                  ...
# 28957  MULTILINESTRING ((-97.11556803066 49.943945001...
# 28958  MULTILINESTRING ((-97.134404708765 49.90567402...
# 28959  MULTILINESTRING ((-97.125132844509 49.91383316...
# 28960  MULTILINESTRING ((-97.128799417643 49.90276360...
# 28961  MULTILINESTRING ((-97.166080505433 49.85378090...
#
# [28962 rows x 20 columns]

# %%
DF = DF.loc[:,["Block ID","Street Name","Street Type","Number of Lanes","Oneway","Speed Limit","Location"]].rename(columns={"Street Name":"Street"})
__clean_string = lambda l: np.array([[(float(j.split()[1]),float(j.split()[0])) for j in m] for m in l],dtype=object)
DF.loc[:,"Location"] = __clean_string(DF["Location"].str.replace("MULTILINESTRING \(\(|\)\)","",regex=True).str.split(", "))
DF.loc[:,"Num_Points"] = [len(i) for i in DF["Location"].values]
DF
# Out:
#        Block ID       Street Street Type  Number of Lanes  Oneway  \
# 0        1873.0       Sifton          Rd              2.0       0
# 1       23974.0        Valde         Ave              2.0       0
# 2       23779.0  Lagimodiere        Blvd              2.0       1
# 3       70342.0   Sage Creek        Blvd              2.0       2
# 4       24031.0        Point          Rd              2.0       0
# ...         ...          ...         ...              ...     ...
# 28957   17669.0       Newton         Ave              2.0       0
# 28958   23040.0         Main          St              3.0       1
# 28959   18560.0        Digby         Ave              2.0       0
# 28960   24835.0     Disraeli         Fwy              3.0       2
# 28961    4370.0       Taylor         Ave              2.0       2
#
#        Speed Limit                                           Location  \
# 0               50  [(49.810557383041, -97.143794801994), (49.8105...
# 1               50  [(49.910940712709, -97.003620088172), (49.9109...
# 2               80  [(49.8671557845, -97.066599484474), (49.869726...
# 3               50  [(49.833747499855, -97.049568380871), (49.8337...
# 4               50  [(49.846976634414, -97.145356293446), (49.8472...
# ...            ...                                                ...
# 28957           50  [(49.943945001092, -97.11556803066), (49.94406...
# 28958           50  [(49.905674025615, -97.134404708765), (49.9062...
# 28959           50  [(49.913833165245, -97.125132844509), (49.9138...
# 28960           60  [(49.902763600349, -97.128799417643), (49.9028...
# 28961           60  [(49.853780904888, -97.166080505433), (49.8533...
#
#        Num_Points
# 0               2
# 1               2
# 2               2
# 3               2
# 4               2
# ...           ...
# 28957          21
# 28958           5
# 28959          34
# 28960          14
# 28961          11
#
# [28962 rows x 8 columns]

# %%
DF.to_csv("clean_datasets/ROAD_NETWORK.csv")

# %%
# [" ".join(map(str,val)) for val in DF[["Street Name","Street Type","Street Direction"]].fillna("").values]
