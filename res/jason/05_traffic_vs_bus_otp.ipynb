# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import myutils as u
import math

# %% [markdown]
# Outline
# 1. Datasets Used
#     - Bus OTP data & Bus stops information
#         - Bus stop OTP: {Time, Exact Location, Street, Direction, Bus Lateness}
#     - Traffic count data & Traffic count sites information
#         - Features: {Time*, Exact Location, Street, Directional traffic volume, Aggregrate traffic volume}
#
# 2. Goal:
#     - Link Traffic volume to Bus Lateness
#
# 3. Specifics:
# - Time Period: 1 month data (Aug/Sep/Oct 2021)
# - Affected Bus stops:
#     - Direct zone: Bus stops on the same street and direction, within 100m
#     - Indirect zone: Bus stops not categorized as in Direct Zone but within 100m
# - Bus lateness entries:
#     - All bus time entries within time interval [T-15min,T]
#
# 4. Hypothesis:
# -  Traffic count affects bus lateness
#     - Main Hypothesis: Bus on the same street and direction will be directly affected
#     - Traffic spillover effects: Other streets in the indirect zone will also experience similar traffic volume and will be impacted too
# - Other potentially relevant factors:
#     - Distance might matter: The farther the bus stop is away from a count, the weaker the relationship might be (People turning to other streets)?
#     - Number of lanes: (Not accounted for in the original data) More lanes per traffic might mean less lateness?
#     - Directions: Bus stops towards the site vs bus stops away from the site
#
# 5. Approach
# - Data Preparation:
#     - Match: Street, Direction
#     - Approximate: Time, Location (within a radius)
#     - Direct factors: Traffic volume - Bus Lateness
#     - Other factors: Distance (stop - count site), Aggregate traffic volume

# %%
# SITES = u.import_data("SITES")
# pt1 = tuple(SITES.iloc[0][["Lat","Long"]])
# pt2 = tuple(SITES.iloc[1][["Lat","Long"]])
# d = u.distance(pt1,pt2)
# print(pt1,pt2,d)

# %% [markdown]
# <!-- Column	How to prepare	Source
# Bus stops	Select bus stops in the radius of the traffic count (radius=500)	STOPS.csv
# Distance	Use lat, long to calculate distance to the site	STOPS.csv
# Same Street	Compare street name of stop vs traffic count site	STOPS.csv
# Same Direction	Traffic volume in the direction of the stop	TRAFFIC COUNT.csv
# Opposite	Traffic volume in the other direction	TRAFFIC COUNT.csv
# Total	Total volume	TRAFFIC COUNT.csv
# Mean OTP	Collect Bus OTP in the time frame, calculate the mean	ON_TIME.csv
# Interval	Time -> converted to float hh.mm	ON_TIME.csv
# Num Lanes	Match  number of lanes based on street name (optional). Might be a bit complicated since different part of the same streets may have different num lanes	ROAD NETWORKS.csv -->

# %% [markdown]
# Location: Disraeli Bridge
# Time: 4:45 - 5 pm Aug 20 2021
# Bus stops within Radius = 500m

# %%
ALL_SITES = u.import_data("SITES")
ALL_STOPS = u.import_data("STOPS")
ALL_TRAFFIC_COUNTS = u.import_data("TRAFFIC_COUNTS")
ALL_LANE_CLOSURE = u.import_data("LANE_CLOSURE")
ALL_ON_TIME = u.import_data("ON_TIME")
ALL_ROAD_NETWORK = u.import_data("ROAD_NETWORK")

# %%
TC_SITE = ALL_SITES[ALL_SITES["Street"] == "McPhillips"]
MIN = pd.to_timedelta("1 min")
time = pd.to_datetime("2021-08-20 17:00:00")
TRAFFIC_COUNTS = ALL_TRAFFIC_COUNTS[(ALL_TRAFFIC_COUNTS["Timestamp"]==time) & (ALL_TRAFFIC_COUNTS["Street"]==TC_SITE["Street"].item())]
TRAFFIC_COUNTS.loc[:,"fmt_Timestamp"] = [u.fmt_timestamp(i) for i in TRAFFIC_COUNTS["Timestamp"]]

radius = 500 # meters
site_coords = TC_SITE[["Lat","Long"]].values[0]
stop_coords = ALL_STOPS[["Stop Number","Lat","Long"]].set_index("Stop Number").values
distances = u.distance_within(site_coords,stop_coords,radius,key=None)
AFF_STOPS = ALL_STOPS.iloc[distances["index"]]  
AFF_STOPS
# Out:
# /Users/jasetran/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
#       Stop Number                                          Stop Name  \
# 1483        30199                          Westbound Leila at Watson
# 1628        30353               Northbound McPhillips at Leila North
# 1637        30362                Westbound Leila at Garden Park West
# 1638        30363                 Westbound Leila at McPhillips East
# 1639        30364  Southbound Garden City Terminal at Garden City...
# 1640        30365                 Westbound Leila at McPhillips West
# 1641        30366  Westbound Leila at Watson East (Seven Oaks Hos...
# 1646        30371                      Eastbound Leila at Leila Loop
# 1647        30372                     Eastbound Leila at Watson East
# 1649        30374                     Southbound McPhillips at Leila
# 1650        30375                     Northbound McPhillips at Leila
# 1651        30376                 Eastbound Leila at McPhillips East
# 1652        30377  Northbound Garden City Terminal at Garden City...
# 1654        30379  Southbound Garden City Terminal at Garden City...
# 1661        30386                 Northbound McPhillips at Kingsbury
# 1668        30393                 Southbound McPhillips at Kingsbury
# 1669        30394                     Southbound McPhillips at Canna
# 1672        30397           Northbound McPhillips at Kingsbury South
# 1974        30721    Eastbound Leila at Watson (Seven Oaks Hospital)
# 2025        30779  Northbound Garden City Terminal at Garden City...
# 2026        30780  Northbound Garden City Terminal at Garden City...
# 2118        30884                     Southbound McPhillips at Court
# 2123        30890  Southbound Garden City Terminal at Garden City...
# 2124        30891                      Westbound Court at McPhillips
# 2150        30918                         Southbound Watson at Leila
# 2151        30919                     Southbound Watson at Kingsbury
# 2157        30925               Northbound Watson at Kingsbury South
# 2158        30926                     Northbound Watson at Kingsbury
# 2159        30927                         Northbound Watson at Leila
#
#             Lat       Long   Direction                Street  \
# 1483  49.954980 -97.152048   Westbound                 Leila
# 1628  49.954245 -97.146611  Northbound            McPhillips
# 1637  49.952320 -97.143785   Westbound                 Leila
# 1638  49.953020 -97.145947   Westbound                 Leila
# 1639  49.952219 -97.145322  Southbound  Garden City Terminal
# 1640  49.953873 -97.148619   Westbound                 Leila
# 1641  49.954478 -97.150478   Westbound                 Leila
# 1646  49.954954 -97.153220   Eastbound                 Leila
# 1647  49.953885 -97.149413   Eastbound                 Leila
# 1649  49.952922 -97.148237  Southbound            McPhillips
# 1650  49.952684 -97.147967  Northbound            McPhillips
# 1651  49.952683 -97.145653   Eastbound                 Leila
# 1652  49.952362 -97.145247  Northbound  Garden City Terminal
# 1654  49.951873 -97.145601  Southbound  Garden City Terminal
# 1661  49.951194 -97.149293  Northbound            McPhillips
# 1668  49.950483 -97.150380  Southbound            McPhillips
# 1669  49.949170 -97.151531  Southbound            McPhillips
# 1672  49.949243 -97.151013  Northbound            McPhillips
# 1974  49.954462 -97.151175   Eastbound                 Leila
# 2025  49.952060 -97.145538  Northbound  Garden City Terminal
# 2026  49.952220 -97.145406  Northbound  Garden City Terminal
# 2118  49.955539 -97.145920  Southbound            McPhillips
# 2123  49.952112 -97.145396  Southbound  Garden City Terminal
# 2124  49.955847 -97.147219   Westbound                 Court
# 2150  49.953747 -97.152555  Southbound                Watson
# 2151  49.952156 -97.153773  Southbound                Watson
# 2157  49.950389 -97.155235  Northbound                Watson
# 2158  49.951673 -97.153931  Northbound                Watson
# 2159  49.953877 -97.152243  Northbound                Watson
#
#                                             At
# 1483                                    Watson
# 1628                               Leila North
# 1637                          Garden Park West
# 1638                           McPhillips East
# 1639    Garden City Centre (71 via McPhillips)
# 1640                           McPhillips West
# 1641         Watson East (Seven Oaks Hospital)
# 1646                                Leila Loop
# 1647                               Watson East
# 1649                                     Leila
# 1650                                     Leila
# 1651                           McPhillips East
# 1652      Garden City Centre (71 via Sinclair)
# 1654                   Garden City Centre (18)
# 1661                                 Kingsbury
# 1668                                 Kingsbury
# 1669                                     Canna
# 1672                           Kingsbury South
# 1974              Watson (Seven Oaks Hospital)
# 2025      Garden City Centre (17 Misericordia)
# 2026    Garden City Centre (77 Kildonan Place)
# 2118                                     Court
# 2123  Garden City Centre (17 Seven Oaks 77 PP)
# 2124                                McPhillips
# 2150                                     Leila
# 2151                                 Kingsbury
# 2157                           Kingsbury South
# 2158                                 Kingsbury
# 2159                                     Leila

# %%
ON_TIME = ALL_ON_TIME[(ALL_ON_TIME["Scheduled Time"] <= time) & (ALL_ON_TIME["Scheduled Time"] > time -15*MIN)]

DF = AFF_STOPS.loc[:,["Stop Number"]]
DF.loc[:,"Distance"] = distances["distance"]
DF.loc[:,"Street"] = (AFF_STOPS["Street"] == TRAFFIC_COUNTS["Street"].item()).replace({True:1,False:0})
DF.loc[(AFF_STOPS["Street"] != TC_SITE["Street"].item()),"Directional"] = 0
for dir in ["Northbound","Southbound","Eastbound","Westbound"]:
    DF.loc[(AFF_STOPS["Street"] == TC_SITE["Street"].item()) & (AFF_STOPS["Direction"] == dir),"Directional"] = TRAFFIC_COUNTS[dir].item()
DF.loc[:,"Total"] = TRAFFIC_COUNTS["Total"].item()
DF.loc[:,["Arrivals","Average OTP"]] = [(len(ON_TIME.loc[ON_TIME["Stop Number"]==i,"Deviation"].values),ON_TIME.loc[ON_TIME["Stop Number"]==i,"Deviation"].values.mean()) for i in AFF_STOPS["Stop Number"]]

DF.sort_values("Distance")
# Out:
# <ipython-input-4-9f48671c32fc>:10: RuntimeWarning: Mean of empty slice.
#   DF.loc[:,["Arrivals","Average OTP"]] = [(len(ON_TIME.loc[ON_TIME["Stop Number"]==i,"Deviation"].values),ON_TIME.loc[ON_TIME["Stop Number"]==i,"Deviation"].values.mean()) for i in AFF_STOPS["Stop Number"]]
# /Users/jasetran/.local/lib/python3.8/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#       Stop Number    Distance  Street  Directional  Total  Arrivals  \
# 1661        30386   62.842201       1        375.0    687         3
# 1650        30375  130.469948       1        375.0    687         3
# 1649        30374  144.105377       1        312.0    687         2
# 1668        30393  169.375110       1        312.0    687         2
# 1640        30365  240.027105       0          0.0    687         1
# 1647        30372  241.157455       0          0.0    687         1
# 1654        30379  246.263428       0          0.0    687         4
# 2025        30779  252.923932       0          0.0    687         1
# 1638        30363  263.378003       0          0.0    687         3
# 2123        30890  263.809125       0          0.0    687         2
# 1651        30376  264.104329       0          0.0    687         3
# 2026        30780  265.313082       0          0.0    687         0
# 1639        30364  271.147088       0          0.0    687         1
# 1652        30377  279.968505       0          0.0    687         0
# 1672        30397  311.422344       1        375.0    687         3
# 1641        30366  322.652257       0          0.0    687         1
# 1628        30353  329.076830       1        375.0    687         2
# 2159        30927  331.439841       0          0.0    687         1
# 1669        30394  336.830334       1        312.0    687         1
# 2150        30918  337.529056       0          0.0    687         1
# 1974        30721  340.404675       0          0.0    687         2
# 2151        30919  342.831977       0          0.0    687         1
# 2158        30926  350.956296       0          0.0    687         1
# 1637        30362  381.455906       0          0.0    687         4
# 1483        30199  421.070384       0          0.0    687         0
# 1646        30371  467.449780       0          0.0    687         1
# 2157        30925  468.780146       0          0.0    687         1
# 2124        30891  476.053019       0          0.0    687         2
# 2118        30884  478.698274       1        312.0    687         1
#
#       Average OTP
# 1661    98.333333
# 1650    69.666667
# 1649  -152.500000
# 1668  -137.000000
# 1640   -33.000000
# 1647  -101.000000
# 1654   -22.750000
# 2025  -114.000000
# 1638   -80.333333
# 2123   -45.000000
# 1651    29.333333
# 2026          NaN
# 1639    52.000000
# 1652          NaN
# 1672    88.000000
# 1641    -4.000000
# 1628   -43.000000
# 2159    21.000000
# 1669  -184.000000
# 2150   -87.000000
# 1974   -42.000000
# 2151   -77.000000
# 2158     1.000000
# 1637    53.000000
# 1483          NaN
# 1646   -49.000000
# 2157     8.000000
# 2124   -40.000000
# 2118   -16.000000

# %% [markdown]
# Aggregating data for 1hr or more instead of just every 15min

# %%
TC_SITE = ALL_SITES[ALL_SITES["Street"] == "McPhillips"]
MIN = pd.to_timedelta("1 min")
DAY = pd.to_timedelta("1 day")
time = pd.to_datetime("2021-08-20")
TRAFFIC_COUNTS = ALL_TRAFFIC_COUNTS[(ALL_TRAFFIC_COUNTS["Timestamp"]>=time) & (ALL_TRAFFIC_COUNTS["Timestamp"]<time+1*DAY) & (ALL_TRAFFIC_COUNTS["Street"]==TC_SITE["Street"].item())]
TRAFFIC_COUNTS.loc[:,"Time Interval"] = [u.fmt_timestamp(i) for i in TRAFFIC_COUNTS["Timestamp"]]
TRAFFIC_COUNTS.sort_values("Time Interval")
# Out:
# /Users/jasetran/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
#                 Timestamp                                Site  Northbound  \
# 17688 2021-08-20 00:00:00  McPhillips And 190m South Of Leila       105.0
# 17960 2021-08-20 00:15:00  McPhillips And 190m South Of Leila        78.0
# 17872 2021-08-20 00:30:00  McPhillips And 190m South Of Leila        50.0
# 17773 2021-08-20 00:45:00  McPhillips And 190m South Of Leila        45.0
# 17729 2021-08-20 01:00:00  McPhillips And 190m South Of Leila        42.0
# ...                   ...                                 ...         ...
# 18016 2021-08-20 22:45:00  McPhillips And 190m South Of Leila       138.0
# 17687 2021-08-20 23:00:00  McPhillips And 190m South Of Leila       122.0
# 18173 2021-08-20 23:15:00  McPhillips And 190m South Of Leila       147.0
# 17895 2021-08-20 23:30:00  McPhillips And 190m South Of Leila       122.0
# 17983 2021-08-20 23:45:00  McPhillips And 190m South Of Leila        95.0
#
#        Southbound  Eastbound  Westbound  Total        Lat       Long  \
# 17688        45.0        0.0        0.0    150  49.951733 -97.149032
# 17960        64.0        0.0        0.0    142  49.951733 -97.149032
# 17872        43.0        0.0        0.0     93  49.951733 -97.149032
# 17773        56.0        0.0        0.0    101  49.951733 -97.149032
# 17729        32.0        0.0        0.0     74  49.951733 -97.149032
# ...           ...        ...        ...    ...        ...        ...
# 18016       115.0        0.0        0.0    253  49.951733 -97.149032
# 17687       119.0        0.0        0.0    241  49.951733 -97.149032
# 18173        89.0        0.0        0.0    236  49.951733 -97.149032
# 17895       101.0        0.0        0.0    223  49.951733 -97.149032
# 17983        84.0        0.0        0.0    179  49.951733 -97.149032
#
#            Street   Near  Time Interval
# 17688  McPhillips  Leila           0.00
# 17960  McPhillips  Leila           0.25
# 17872  McPhillips  Leila           0.50
# 17773  McPhillips  Leila           0.75
# 17729  McPhillips  Leila           1.00
# ...           ...    ...            ...
# 18016  McPhillips  Leila          22.75
# 17687  McPhillips  Leila          23.00
# 18173  McPhillips  Leila          23.25
# 17895  McPhillips  Leila          23.50
# 17983  McPhillips  Leila          23.75
#
# [96 rows x 12 columns]

# %%
freq = "1h"
day = pd.to_datetime("2021-08-20")
cols = ["Northbound","Southbound","Eastbound","Westbound","Total"]
time_range = day + pd.timedelta_range(start="0:00:00",end="24:00:00",freq=freq)
df = pd.DataFrame()
for i in range(len(time_range)-1):
    lower_lim = time_range[i]
    upper_lim = time_range[i+1]
    res = TRAFFIC_COUNTS[TRAFFIC_COUNTS["Timestamp"] == upper_lim]
    res.loc[:,cols] = TRAFFIC_COUNTS.loc[(TRAFFIC_COUNTS["Timestamp"] <= upper_lim) & (TRAFFIC_COUNTS["Timestamp"] > lower_lim),cols].sum(axis=0).values
    df = pd.concat([df,res])
df
# Out:
# /Users/jasetran/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1797: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, v, pi)
#                 Timestamp                                Site  Northbound  \
# 17729 2021-08-20 01:00:00  McPhillips And 190m South Of Leila       215.0
# 17656 2021-08-20 02:00:00  McPhillips And 190m South Of Leila       120.0
# 17661 2021-08-20 03:00:00  McPhillips And 190m South Of Leila        90.0
# 17814 2021-08-20 04:00:00  McPhillips And 190m South Of Leila       121.0
# 17874 2021-08-20 05:00:00  McPhillips And 190m South Of Leila       125.0
# 17883 2021-08-20 06:00:00  McPhillips And 190m South Of Leila       237.0
# 17879 2021-08-20 07:00:00  McPhillips And 190m South Of Leila       498.0
# 17772 2021-08-20 08:00:00  McPhillips And 190m South Of Leila       790.0
# 17809 2021-08-20 09:00:00  McPhillips And 190m South Of Leila       893.0
# 17764 2021-08-20 10:00:00  McPhillips And 190m South Of Leila       993.0
# 17749 2021-08-20 11:00:00  McPhillips And 190m South Of Leila      1080.0
# 17733 2021-08-20 12:00:00  McPhillips And 190m South Of Leila      1294.0
# 18310  McPhillips  Leila           17.0
# 18262  McPhillips  Leila           18.0
# 18231  McPhillips  Leila           19.0
# 17655  McPhillips  Leila           20.0
# 17698  McPhillips  Leila           21.0
# 17721  McPhillips  Leila           22.0
# 17687  McPhillips  Leila           23.0

# %%
DF1 = pd.DataFrame()
for timestamp in df["Timestamp"]:
    ON_TIME = ALL_ON_TIME[(ALL_ON_TIME["Scheduled Time"] <= time) & (ALL_ON_TIME["Scheduled Time"] > time - pd.to_timedelta(freq))]
    df_ = df[df["Timestamp"] == timestamp]

    df1 = AFF_STOPS.loc[:,["Stop Number"]]
    df1.loc[:,"Distance"] = distances["distance"]
    df1.loc[:,"Street"] = (AFF_STOPS["Street"] == df_["Street"].item()).replace({True:1,False:0})
    df1.loc[(AFF_STOPS["Street"] != TC_SITE["Street"].item()),"Directional"] = 0
    for dir in ["Northbound","Southbound","Eastbound","Westbound"]:
        df1.loc[(AFF_STOPS["Street"] == TC_SITE["Street"].item()) & (AFF_STOPS["Direction"] == dir),"Directional"] = df_[dir].item()
    df1.loc[:,"Total"] = df_["Total"].item()
    df1.loc[:,["Arrivals","Average OTP"]] = [(len(ON_TIME.loc[ON_TIME["Stop Number"]==i,"Deviation"].values),ON_TIME.loc[ON_TIME["Stop Number"]==i,"Deviation"].values.mean()) for i in AFF_STOPS["Stop Number"]]
    df1.loc[:,"Time interval"] = u.fmt_timestamp(timestamp)
    DF1 = pd.concat([DF1,df1])

DF1
# Out:
# <ipython-input-62-a63613fdd0a7>:13: RuntimeWarning: Mean of empty slice.
#   df1.loc[:,["Arrivals","Average OTP"]] = [(len(ON_TIME.loc[ON_TIME["Stop Number"]==i,"Deviation"].values),ON_TIME.loc[ON_TIME["Stop Number"]==i,"Deviation"].values.mean()) for i in AFF_STOPS["Stop Number"]]
# /Users/jasetran/.local/lib/python3.8/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#       Stop Number    Distance  Street  Directional   Total  Arrivals  \
# 1483        30199  421.070384       0          0.0   410.0         1
# 1628        30353  329.076830       1        215.0   410.0         1
# 1637        30362  381.455906       0          0.0   410.0         2
# 1638        30363  263.378003       0          0.0   410.0         2
# 1639        30364  271.147088       0          0.0   410.0         1
# ...           ...         ...     ...          ...     ...       ...
# 2150        30918  337.529056       0          0.0  1058.0         0
# 2151        30919  342.831977       0          0.0  1058.0         0
# 2157        30925  468.780146       0          0.0  1058.0         0
# 2158        30926  350.956296       0          0.0  1058.0         0
# 2159        30927  331.439841       0          0.0  1058.0         0
#
#       Average OTP  Time interval
# 1483       -135.0            1.0
# 1628        249.0            1.0
# 1637         85.5            1.0
# 1638         35.0            1.0
# 1639        251.0            1.0
# ...           ...            ...
# 2150          NaN           23.0
# 2151          NaN           23.0
# 2157          NaN           23.0
# 2158          NaN           23.0
# 2159          NaN           23.0
#
# [667 rows x 8 columns]

# %%
DF1.dropna()
# Out:
#       Stop Number    Distance  Street  Directional   Total  Arrivals  \
# 1483        30199  421.070384       0          0.0   410.0         1
# 1628        30353  329.076830       1        215.0   410.0         1
# 1637        30362  381.455906       0          0.0   410.0         2
# 1638        30363  263.378003       0          0.0   410.0         2
# 1639        30364  271.147088       0          0.0   410.0         1
# ...           ...         ...     ...          ...     ...       ...
